# %%
import pandas as pd

# %%
report = pd.read_csv('../../../kan_feynman_results.csv')
avg_symbolic = report['R2 Score'].mean()
avg_KAN = report['R2 Score KAN'].mean()

print(avg_symbolic)
print(avg_KAN)
# Out:
# 0.4900809320910224
# 0.9201355001022076

# %%
symbolic_above = (report['R2 Score'] > 0.99).sum()
kan_above = (report['R2 Score KAN'] > 0.99).sum()

print(symbolic_above)
print(kan_above)
# Out:
# 5
# 12
