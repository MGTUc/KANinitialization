# %%
import pandas as pd

# %%
report = pd.read_csv('../../../kan_feynman_results_KAN.csv')
avg_symbolic = report['R2 Score'].median()
avg_KAN = report['R2 Score KAN'].median()

print(avg_symbolic)
print(avg_KAN)
# Out:
# 0.2001298069953918
# 0.9888287782669068

# %%
symbolic_above = (report['R2 Score'] > 0.99).sum()
kan_above = (report['R2 Score KAN'] > 0.99).sum()

print(symbolic_above)
print(kan_above)
# Out:
# 3
# 13

# %%
report[report['R2 Score KAN'] > 0.99][['MLPKAN time','Conversion time','KAN training time']].sum(axis=1).mean()
# report[report['R2 Score KAN'] > 0.99][['KAN time']].mean()
# Out:
# KAN time    0.611624
# dtype: float64
